# %% [markdown]
# # Lab - 5 - Data Preprocessing

# %% [markdown]
# <h1>Ayushi Patel</h1>
# <h2>23010101199</h2>

# %% [markdown]
# ### 1)  First, you need to read the titanic dataset from local disk and display Last five records

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### 2)  Handle Missing Values in data set [use dropna(), fillna(), and interpolate]

# %%
data = df.dropna(how="any",axis=1) # deletes the columns having any single or more values null
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df['Age'] = None # to add the null value we assign it with none

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = df.dropna(how="all",axis=1) #it delete the column which contains all the null value
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
#withfillna

newdata = df.copy()
data_withfillna = newdata.fillna("xyz") #fills null value with given variable
data_withfillna = newdata.fillna({'Age': 35,'Cabin':"Not Aval"})
data_withfillna
meanAge= df.Age.mean()
meanAge
modeCabin =df.Cabin.mode()
modeCabin
modeCabin =df.Cabin.mode()[0][0:3]
modeCabin
data_withfillna = newdata.fillna({'Cabin':'B96'})
data_withfillna
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_withinterpolate = newdata.interpolate()
data_withinterpolate
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_18516\519773704.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_withinterpolate = newdata.interpolate()
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  None      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  None      1
# ...

# %% [markdown]
# ### 3)  Apply Scaling to AGE attribute with min max, decimal scaling and z score.

# %%
puredata = df.copy()
puredata['Age'] = puredata['Age'].interpolate()
puredata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#using min-max normalization
data_minmax = puredata.copy()
age_mm = data_minmax['Age']
age_min = age_mm.min()
age_max = age_mm.max()
data_minmax['MinMaxAge'] = (age_mm - age_min)/(age_max - age_min)
data_minmax[['Age','MinMaxAge']]
# Out:
#       Age  MinMaxAge
# 0    22.0   0.271174
# 1    38.0   0.472229
# 2    26.0   0.321438
# 3    35.0   0.434531
# 4    35.0   0.434531
# ..    ...        ...
# 886  27.0   0.334004
# 887  19.0   0.233476
# 888  22.5   0.277457
# 889  26.0   0.321438
# 890  32.0   0.396833
#
# [891 rows x 2 columns]

# %%
#Using decimal scaling
data_ds = puredata.copy()
age_ds = data_ds['Age']
max_age = age_ds.max()
temp = len(str(int(max_age)))
print(max_age)
print(temp)
data_ds['DecimalScaleAge'] = age_ds/(10**temp)
data_ds[['Age','DecimalScaleAge']]
# Out:
# 80.0
# 2
#       Age  DecimalScaleAge
# 0    22.0            0.220
# 1    38.0            0.380
# 2    26.0            0.260
# 3    35.0            0.350
# 4    35.0            0.350
# ..    ...              ...
# 886  27.0            0.270
# 887  19.0            0.190
# 888  22.5            0.225
# 889  26.0            0.260
# 890  32.0            0.320
#
# [891 rows x 2 columns]

# %%
# Z scaling
data_zs = puredata.copy()
age_zs = data_zs['Age']
age_mean = age_zs.mean()
age_std = age_zs.std()
data_zs['ZScoreAge'] = (age_zs - age_mean)/age_std
data_zs[['Age','ZScoreAge']]
# Out:
#       Age  ZScoreAge
# 0    22.0  -0.555738
# 1    38.0   0.595147
# 2    26.0  -0.268017
# 3    35.0   0.379356
# 4    35.0   0.379356
# ..    ...        ...
# 886  27.0  -0.196086
# 887  19.0  -0.771528
# 888  22.5  -0.519772
# 889  26.0  -0.268017
# 890  32.0   0.163565
#
# [891 rows x 2 columns]
